# %%
import sys 
sys.path.append('/home/tamak/master_exp/session-rec')

# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd 

df = pd.read_csv('../data/30music/raw/30music-200ks.csv', sep = '\t')

# %%
df
# Out:
#          UserId  SessionId   ItemId        Time  ArtistId
# 0         27063    1889046  2691760  1402997433    337496
# 1         27063    1889046  2691717  1402997784    337496
# 2         27063    1889046  2691636  1402998064    337496
# 3         27063    1889046  2691702  1402998298    337496
# 4         27063    1889046  2691783  1402998576    337496
# ...         ...        ...      ...         ...       ...
# 3707852   14197    1530643  2083564  1417872723    261201
# 3707853   14197    1530643  2033311  1417872848    254439
# 3707854   14197    1530643  2009127  1417873121    251866
# 3707855   14197    1530643  2009133  1417873433    251866
# 3707856   14197    1530643  2009078  1417873705    251866
#
# [3707857 rows x 5 columns]

# %%
df2 = pd.DataFrame(df.groupby(['UserId', 'SessionId']).size().sort_values())

# %%
df2
# Out:
#                      0
# UserId SessionId
# 12439  1705633       5
# 27128  1603972       5
# 39909  360326        5
# 42998  450833        5
# 14818  1203362       5
# ...                ...
# 39695  2245625    1066
# 40063  350389     1461
# 40181  146314     1965
# 40283  82114      2000
#        82653      4913
#
# [200000 rows x 1 columns]

# %%
df3  = pd.DataFrame(df2.groupby(['SessionId']).size())
df3[ df3[0] > 1 ]
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %%
df3[ df3[0] == 1 ]
# Out:
#            0
# SessionId
# 65         1
# 180        1
# 181        1
# 182        1
# 183        1
# ...       ..
# 2764439    1
# 2764443    1
# 2764449    1
# 2764452    1
# 2764462    1
#
# [200000 rows x 1 columns]

# %% [markdown]
# # spd modify

# %%
df = pd.read_csv( '../spotify_playlists_dataset/spotify_dataset.csv', sep = '","')
_ITEM_FEATURES = """user_id | artistname | trackname | playlistname"""

item_features = map(lambda f: f.replace('\n', '').replace(' ', '-').lower(), _ITEM_FEATURES.split(' | '))
df.columns = item_features

df
# Out:
# /home/tamak/anaconda3/envs/srec37/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6428/2731910102.py in <module>
#       3
#       4 item_features = map(lambda f: f.replace('\n', '').replace(' ', '-').lower(), _ITEM_FEATURES.split(' | '))
# ----> 5 df.columns = item_features
#       6
#       7 df
#
# ~/anaconda3/envs/srec37/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# ...
